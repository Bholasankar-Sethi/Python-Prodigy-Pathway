# %%
print("Ram")
print(7)
print('n')
print(7/2)
print(5//2)
print(3.8273)
# Out:
# Ram
# 7
# n
# 3.5
# 2
# 3.8273

# %%
name = "Hari"
print(name)
Name = "rohan"
print("His name :", Name)
age = 38
print("He is ", age)
print("After 3 year: ", age+3)
a, A = 2, 3
print(a, A)
stu_1 = "Janana"
stu2 = "Mohan"
print(stu_1, stu2)
# Out:
# Hari
# His name : rohan
# He is  38
# After 3 year:  41
# 2 3
# Janana Mohan

# %%
Name = "Sritam"
age = 28
hight = 281.23
agree = True
go = None
print(Name, age, agree, go, hight)
print(type(Name))
print(type(age))
print(type(hight))
print(type(agree))
print(type(go))
# Out:
# Sritam 28 True None 281.23
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
a = 5
b = 7
sum = a + b
print(sum)
cost, profit = 278, 173
print("Mark price:", cost + profit)
print(a-2)
print(sum+a-b)
print(a+b*sum)
print((a + b)* sum)
# Out:
# 12
# Mark price: 451
# 3
# 10
# 89
# 144

# %%
a = 3
b = 2
str = "t"
txt = "%"
print(a * txt * b)
print(a * str * b)

# sting + string operation
a, b = '4',5  
sym = "@"
print((a + sym)* b)

name = "Jyoti"
print(b * name)  # string name repeat b times


# a, b , c = 3,4,"H"
# print(a * c * b)

# name = "Madhaba"
# print((name+c)*b)
# print(4 * name)
# Out:
# %%%%%%
# tttttt
# 4@4@4@4@4@
# JyotiJyotiJyotiJyotiJyoti

# %%
a, b = 5,2
print(a/b)
print(a//b)
print(type(a//b))

A,B = 8,4
print(A/B)
print(type(A/B))
# Out:
# 2.5
# 2
# <class 'int'>
# 2.0
# <class 'float'>

# %%
#Floor division always give lower bound
a,b = 3, 2
print(a/b)
print(a//b)

a,b = 5, -2
print(a/b)
print(a//b)

a,b = -5, 3
print(a/b)
print(a//b)

a,b = -7,-3
print(a/b)
print(a//b)
# Out:
# 1.5
# 1
# -2.5
# -3
# -1.6666666666666667
# -2
# 2.3333333333333335
# 2

# %%
'''Modulo operator'''

a,b = 16,5
print(a % b)

a,b = 16, -5
print(a % b)

a,b = -16, 5
print(a % b)

a, b = -16, -5
print(a % b)
# Out:
# 1
# -4
# 4
# -1

# %%
# single line comment
""""Multi LIne Comment"""
'''print("Hello World)'''
"""print("Your name")"""
name = 3

# %%
name = input("Name: ")
print(name)
# Out:
# Jagan

# %%
# Ternary Condition // One line conditional
food = input("Food Name: ")
oredr = "Yes Confirm" if food == "Biriyani" else "I do not like it"
print("Order: ", oredr)
# Out:
# Order:  Yes Confirm

# %%
food = input("Food Name: ")
print("Testy") if food == "Biriyani" else print("It is not Testy")
# Out:
# It is not Testy

# %%
age = int(input("What is your age: "))
vote = "You can Vote" if age >= 18 and age <150 else "You are not elligible"
print(vote)

if age >= 18 and age < 150: print("You are adult") 
else: print("You are so young")
print("It is not human age.")

print("Citizenship confirmed") if age >= 18 and age < 150 else print("Not confirmed.")
# Out:
# You can Vote
# You are adult
# It is not human age.
# Citizenship confirmed

# %%
distance = int(input("How far from Utkal: "))
place = input("Where are you From: ")
print("You are From: ", place)
print("As", "",distance, "is your distance.")

print("\n")

# if(distance >100 and place != "bbsr"):
#     print("You are Elligible for Hostel Admission.")
# elif(distance > 100 and place == "bbsr"):
#     print("There is a possibility to get in Hostel.")
# elif(distance <= 100 and place != "bbsr"):
#     print("Wait for 2nd list.")
# else:
#     print("You are not elligible to be a Hosteler.")

if(distance > 100 or place != "BBSR"):
    print('There is a possibility to get in Hostel.')
    #print("Elligible For Hostel Admission.")
elif(distance <= 100 or place == "BBSR"):
    print('You are not Elligible for Hostel.')
    #print("There is a possibility to get Hostel.")
elif(distance > 100 or place == "BBSR"):
    print("Wait for 2nd Selection List.")
else:
    print("You are not elligible for Hosteler.")
    print("Stay Home and safe.")
# Out:
# You are From:  BBSR
# As  76 is your distance.
#
#
# There is a possibility to get Hostel.

# %% [markdown]
# if(distance > 100 or place != "BBSR"):
#     print("Elligible For Hostel Admission.")
# elif(distance > 100 or place == "BBSR"):
#     print("There is a possibility to get Hostel.")
# elif(distance <= 100 or place != "BBSR"):
#     print("Wait for 2nd Selection List.")
# else:
#     print("You are not elligible for Hosteler.")
#     print("Stay Home and safe.")

# %%
age = int (input("How old are you?"))
vote = ("Yes", "No") [age < 18]
print(vote)
# Out:
# Yes

# %%
salary = int(input("How much do you get?"))
tax = salary * (.1, .2) [salary >= 50000]
print("Total Income", salary, "\n" "Tax amount: ", tax)
# Out:
# Total Income 56000
# Tax amount:  11200.0

# %%
a = 9
b = 2
print(a % b)
print(a ** b)
print(a//b)
# Out:
# 1
# 81
# 4

# %%
x,y = 8,3
print(x==y)
print(x<y)
print(x>y)
print("Less equal: ", x<=y, "Greaer equal: ", x>=y)
# Out:
# False
# False
# True
# Less equal:  False Greaer equal:  True

# %%
num = 12
num = num + 10
print("Total =", num)
num += 5
print(num)
num -= 5
print(num)
num *= 3
print(num)
num /= 3
print(num)
num **= 2
print(num)
num //= 3
print(num)
num %= 5
print(num)
# Out:
# Total = 22
# 27
# 22
# 66
# 22.0
# 484.0
# 161.0
# 1.0

# %%
print(not True)
print(not False)

a,b = 3,8
print(not(a > b))
c = a > b 
print(c)

bul1 = True
bul2 = False
print(bul1 and bul2)
print(bul1 or bul2)

x, y = 9,3
print(not((x == y)or (x >y)))
# Out:
# False
# True
# True
# False
# False
# True
# False

# %%
a , b = 5, 2.38
sum = a + b 
print(sum)
print(type(sum))
total = a + a
print(type(total), total)
# Out:
# 7.38
# <class 'float'>
# <class 'int'> 10

# %%
a = 3
b = "8"
print(type(b))
sum = a + int(b) 
print(type(sum), sum)
print(type(b))
b = float(b)
total = (a + b)
print(type(total))
# Out:
# <class 'str'>
# <class 'int'> 11
# <class 'str'>
# <class 'float'>

# %%
num_1 = 53
num_2 = 74.32
all_total = num_1 + num_2
print(all_total)
print(type(all_total))
# Out:
# 127.32
# <class 'float'>

# %%
passion = "Kuli"
num = 440

print(type(passion + str(num)))
print(passion * str(num))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       2 num = 440
#       4 print(type(passion + str(num)))
# ----> 5 print(passion * str(num))
#
# TypeError: can't multiply sequence by non-int of type 'str'
